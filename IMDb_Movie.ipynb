# %% [markdown]
# # A Blockbuster Gauranteed!

# %% [markdown]
# #### Suppose a producer is looking to make a blockbuster movie.
#
# #### He is interested in knowing what makes a movie superhit and all the factors affecting its ratings. He wants to understand which genres are popular among different age groups and genders, which actors/actress are popular, profits made by different movies and whether budget of a movie plays a contributing factor in making a movie superhit!
#
# #### This analysis will help in making an assured blockbuster movie! So let's explore all the movies and analyse various factors associated with them!

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Filtering out the warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the IMDB DataSet

# %%
#to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Read the csv file using 'read_csv'. Please write your dataset location here.

movies = pd.read_csv('Movie+Assignment+Data.csv')
movies
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %% [markdown]
# # Inspecting the Dataframe

# %%
# Check the number of rows and columns in the dataframe

movies.shape
# Out:
# (100, 62)

# %%
# Check the column-wise info of the dataframe

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns 

movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# #### Dataset contains 100 top-rated movies from 2010 to 2016 along with various pieces of information about the movie, genres, its actors, and the voters who have rated these movies online.

# %% [markdown]
# # Data Analysis
#
# ### Let's Reduce the digits

# %% [markdown]
# The numbers in the `budget` and `gross` are too big, compromising its readability. Let's convert the unit of the `budget` and `gross` columns from `$` to `million $` first.

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'

movies['Gross'] = movies['Gross']/1000000
movies['budget'] = movies['budget']/1000000

# %%
#to check if gross and budget are converted to million
movies[['Gross','budget']].head()
# Out:
#         Gross  budget
# 0  151.101803    30.0
# 1  341.268248   150.0
# 2   51.738905    12.0
# 3  100.546139    47.0
# 4   47.695371     9.0

# %% [markdown]
# ### Let's Talk Profit!
#
# Calculating profit for all the movies and inserting it in new column

# %%
# Creating new column 'profit' by subtracting the 'budget' column from the 'gross' column

movies['Profit'] = movies['Gross'] - movies['budget']

# %%
# to verify 'profit' column is created with correct values
movies[['Gross','budget','Profit']].head()
# Out:
#         Gross  budget      Profit
# 0  151.101803    30.0  121.101803
# 1  341.268248   150.0  191.268248
# 2   51.738905    12.0   39.738905
# 3  100.546139    47.0   53.546139
# 4   47.695371     9.0   38.695371

# %%
# Sorting the dataframe with the 'profit' column as reference using the 'sort_values' function.

sorted_movies = movies.sort_values('Profit', ascending = False)

# %%
# Geting top 10 profitable movies by using position based indexing.

top10 = sorted_movies.iloc[0:10,:]
top10
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# 8                        The Dark Knight Rises        2012   250.0
# 45                              The Lego Movie        2014    60.0
# 1                                     Zootopia        2016   150.0
# 41                               Despicable Me        2010    69.0
# 18                                  Inside Out        2015   175.0
#
#          Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225        Doug Walker         Rob Walker                      0
# ...

# %%
def bar_plot_fun(frame, col1, col2):
    plt.figure(figsize = (10,7))

    chart = sns.barplot(x = frame[col1], y = frame[col2])
    chart.set_xticklabels(chart.get_xticklabels(), fontsize=14, rotation=45, ha='right')
    for p in chart.patches:
        chart.annotate(format(p.get_height(), '.1f'), 
                           (p.get_x() + p.get_width() / 2, p.get_height()), 
                           ha = 'center', va = 'center', 
                           xytext = (5, 10), 
                           textcoords = 'offset points',fontsize=12)
    plt.title('Chart for '+col1+' Vs '+col2, fontsize = 25)
    plt.xlabel(col1, fontsize = 20)
    plt.ylabel(col2, fontsize = 20)
    plt.show()

# %%
bar_plot_fun(top10, "Title", "Profit")

# %% [markdown]
# #### Star Wars: The Force Awakens has made the most profit from Top 100 movies with 691.7 million dollars. The Avengers and Deadpool holds second and third position with 403 and 305 millions dollars respectively.

# %% [markdown]
# #### Majority of movies are PG-13 and R rated in Top 100 movies

# %% [markdown]
# #### 81% of Top 100 movies has been made in USA and 11% of the movies are from UK

# %%
#Ploting profit vs budget

plt.figure(figsize = (7,5))
plt.scatter(movies.budget, movies.Profit)

#Adding and formatting the title
plt.title("Profit vs Budget for Movies", fontdict = {'fontsize' : 20, 'color': 'Blue'})

#Adding x and y labels
plt.ylabel("Profit  (in million)", fontdict = {'fontsize' : 15, 'color': 'Blue'})
plt.xlabel("Budget  (in million)", fontdict = {'fontsize' : 15, 'color': 'Blue'})

plt.show()

# %% [markdown]
# #### Observations for above scatterplot
#
#     1. There are some movies with a smaller budget that have made a huge profit whereas there are some movies where despite having a big budget, they still failed to make a remarkable profit.
#     2. Even though these movies are present in top 100 movies, some movies have made negative profit. i.e They have faced
#     loses

# %% [markdown]
# The dataset contains the 100 best performing movies from the year 2010 to 2016. However scatter plot tells a different story. There are some movies with negative profit. Although good movies do incur losses, but there appear to be quite a few movie with losses. Lets have a closer look at this by finding the movies with negative profit.

# %%
#Find the movies with negative profit

neg_profit = movies[movies['Profit']<0]

# to check new dataframe
neg_profit
# Out:
#                           Title  title_year  budget       Gross  \
# 7                       Tangled        2010   260.0  200.807262
# 17             Edge of Tomorrow        2014   178.0  100.189501
# 22                         Hugo        2011   170.0   73.820094
# 28           X-Men: First Class        2011   160.0  146.405371
# 39            The Little Prince        2015    81.2    1.339152
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270
# 56                         Rush        2013    38.0   26.903709
# 66                      Warrior        2011    25.0   13.651662
# 82                      Flipped        2010    14.0    1.752214
# 89                        Amour        2012     8.9    0.225377
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 7          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %%
# to get number of rows and columns of neg_profit dataframe
neg_profit.shape
# Out:
# (11, 63)

# %%
bar_plot_fun(neg_profit, "Title", "Profit")

# %% [markdown]
# #### 1. Above plot shows that 'Hugo' movie has suffered a loss of 96.2 million dollars followed by 'The Little Prince' and 'Edge of Tomorrow'
# #### 2. Despite of having IMDB rating of 8.1 and 8.2, movies 'Rush' and 'Warrior' have suffered some loss as well

# %% [markdown]
# ### Let's check popularity of Content Rating

# %%
y = list(movies["content_rating"].value_counts().index)
sns.set(font_scale=1.5)
bfig1, ax1 = plt.subplots(figsize=(9,9))
ax1.pie(movies["content_rating"].value_counts(),  labels = y, autopct = '%1.2f%%')
plt.title('Distribution of various content Ratings in Top 100 movies', fontsize = 20)
plt.show()

# %% [markdown]
# ### Let's check Origin of the movies

# %%
fig1, ax = plt.subplots(figsize=(9,9))
sns.set(font_scale=1.5)
x = list(movies["Country"].value_counts().index)
ax.pie(movies["Country"].value_counts(),  labels = x, autopct = '%1.2f%%')
plt.title('Country-wise Distribution', fontsize = 20)
plt.show()

# %% [markdown]
# ### The General Audience and the Critics
#
# Column `MetaCritic` is a very popular website where an average score is determined through the scores given by the top-rated critics. Also there is another column `IMDb_rating` which gives the IMDb rating of a movie. This rating is determined by taking the average of hundred-thousands of ratings from the general audience.
#
# #### Finding out the highest rated movies which have been liked by critics and audiences alike.

# %%
# Changing the scale of MetaCritic

movies['MetaCritic'] = movies.MetaCritic/10
movies.MetaCritic
# Out:
# 0      9.3
# 1      7.8
# 2      6.9
# 3      8.1
# 4      9.6
# 5      8.8
# 6      7.2
# 7      7.1
# 8      7.8
# 9      7.5
# 10     6.6
# 11     6.9
# 12     9.2
# 13     8.1
# 14     7.4
# 15     7.2
# 16     NaN
# 17     7.1
# 18     9.4
# 19     7.6
# 20     7.0
# 21     7.9
# 22     8.3
# 23     7.4
# 24     7.4
# 25     7.2
# 26     7.4
# 27     7.4
# 28     6.5
# 29     9.0
# 30     7.6
# 31     7.6
# 32     7.6
# 33     8.0
# 34     9.6
# 35     8.1
# 36     7.5
# 37     6.8
# 38     7.1
# 39     7.0
# 40     6.3
# 41     7.2
# 42     6.4
# 43     7.9
# 44     6.3
# 45     8.3
# 46     6.9
# 47     6.5
# 48     8.3
# 49     8.7
# 50     7.4
# 51     8.6
# 52     NaN
# 53     9.5
# 54     8.1
# 55     8.0
# 56     7.5
# 57     7.4
# 58     8.2
# 59     6.6
# 60     8.2
# 61     7.2
# 62     8.1
# 63     6.2
# 64     7.9
# 65     8.8
# 66     7.1
# 67     9.0
# 68     8.1
# 69     9.6
# 70     9.3
# 71     NaN
# 72     8.8
# 73     8.2
# 74     8.1
# 75     8.4
# ...

# %%
# Finding average ratings

movies['Avg_rating'] = (movies['MetaCritic'] + movies['IMDb_rating'])/2
movies.head()
# Out:
#                    Title  title_year  budget       Gross      actor_1_name  \
# 0             La La Land        2016    30.0  151.101803      Ryan Gosling
# 1               Zootopia        2016   150.0  341.268248  Ginnifer Goodwin
# 2                   Lion        2016    12.0   51.738905         Dev Patel
# 3                Arrival        2016    47.0  100.546139         Amy Adams
# 4  Manchester by the Sea        2016     9.0   47.695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# ...

# %%
#Sorting in descending order of average rating

movies.sort_values('Avg_rating', ascending = False, inplace = True)
movies.head()
# Out:
#                Title  title_year  budget       Gross        actor_1_name  \
# 94           Boyhood        2014     4.0   25.359200      Ellar Coltrane
# 69  12 Years a Slave        2013    20.0   56.667870  QuvenzhanÃ© Wallis
# 18        Inside Out        2015   175.0  356.454367         Amy Poehler
# 0         La La Land        2016    30.0  151.101803        Ryan Gosling
# 12       Toy Story 3        2010   200.0  414.984497           Tom Hanks
#
#          actor_2_name   actor_3_name  actor_1_facebook_likes  \
# 94  Lorelei Linklater  Libby Villari                     230
# 69      Scoot McNairy   Taran Killam                    2000
# 18       Mindy Kaling  Phyllis Smith                    1000
# 0          Emma Stone     Amiée Conn                   14000
# 12  John Ratzenberger    Don Rickles                   15000
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# 94                   193.0                   127.0          7.9      Drama
# ...

# %%
# Find the movies with metacritic-rating < 0.5 and also with the average rating of >8

movies['Diff_rating'] = abs(movies['IMDb_rating'] - movies['MetaCritic'])
UniversalAcclaim = movies[(movies['Diff_rating']<0.5) & (movies['Avg_rating'] >= 8)]
UniversalAcclaim
# Out:
#                                          Title  title_year  budget  \
# 95                                    Whiplash        2014     3.3
# 35                            Django Unchained        2012   100.0
# 93                          Dallas Buyers Club        2013     5.0
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 3                                      Arrival        2016    47.0
# 33                                 The Martian        2015   108.0
# 43                                   Gone Girl        2014    61.0
#
#          Gross         actor_1_name     actor_2_name       actor_3_name  \
# 95   13.092000         J.K. Simmons  Melissa Benoist       Chris Mulkey
# 35  162.804648    Leonardo DiCaprio  Christoph Waltz       Ato Essandoh
# 93   27.296514  Matthew McConaughey  Jennifer Garner       Denis O'Hare
# 97  936.662225          Doug Walker       Rob Walker                  0
# ...

# %%
bar_plot_fun(UniversalAcclaim, "Title", "Avg_rating")

# %% [markdown]
# #### We got above top rated list of movies by finding average of Critics rating and IMDB rating. These movies were liked by general audience and critics both.

# %%
# to reset movie index

movies.reset_index(inplace = True, drop = True)
movies
# Out:
#                                               Title  title_year  budget  \
# 0                                           Boyhood        2014     4.0
# 1                                  12 Years a Slave        2013    20.0
# 2                                        Inside Out        2015   175.0
# 3                                        La La Land        2016    30.0
# 4                                       Toy Story 3        2010   200.0
# 5                             Manchester by the Sea        2016     9.0
# 6                                         Spotlight        2015    20.0
# 7                                           Gravity        2013   100.0
# 8                                   Before Midnight        2013     3.0
# 9                                          Whiplash        2014     3.3
# 10                                            Amour        2012     8.9
# 11                               The Social Network        2010    40.0
# ...

# %% [markdown]
# ### Let's the Most Popular Trios
#
# The metric that we have chosen to check the popularity is the Facebook likes of each of all the actors.
#
# The dataframe has three columns to help you out for the same, viz. `actor_1_facebook_likes`, `actor_2_facebook_likes`, and `actor_3_facebook_likes`. Our objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of `actor_1_facebook_likes`, `actor_2_facebook_likes` and `actor_3_facebook_likes` should be maximum.
# Finding out the top 5 popular trios, and output their names in a list.

# %%
# to covert datatype of 'actor_1_facebook_likes' column to float64

movies.actor_1_facebook_likes = movies.actor_1_facebook_likes.astype('float64')
movies.dtypes
# Out:
# Title                      object
# title_year                  int64
# budget                    float64
# Gross                     float64
# actor_1_name               object
# actor_2_name               object
# actor_3_name               object
# actor_1_facebook_likes    float64
# actor_2_facebook_likes    float64
# actor_3_facebook_likes    float64
# IMDb_rating               float64
# genre_1                    object
# genre_2                    object
# genre_3                    object
# MetaCritic                float64
# Runtime                     int64
# CVotes10                    int64
# CVotes09                    int64
# CVotes08                    int64
# CVotes07                    int64
# CVotes06                    int64
# CVotes05                    int64
# CVotes04                    int64
# CVotes03                    int64
# CVotes02                    int64
# CVotes01                    int64
# CVotesMale                  int64
# ...

# %%
# Extraxting necessary columns in new dataframe
actor_trio = movies[['actor_1_name','actor_2_name','actor_3_name','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes']]

# adding facebook likes of all actors
actor_trio['Total_likes'] = movies['actor_1_facebook_likes'] + movies['actor_2_facebook_likes'] + movies['actor_3_facebook_likes']
actor_trio.head()
# Out:
#          actor_1_name       actor_2_name   actor_3_name  \
# 0      Ellar Coltrane  Lorelei Linklater  Libby Villari
# 1  QuvenzhanÃ© Wallis      Scoot McNairy   Taran Killam
# 2         Amy Poehler       Mindy Kaling  Phyllis Smith
# 3        Ryan Gosling         Emma Stone     Amiée Conn
# 4           Tom Hanks  John Ratzenberger    Don Rickles
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   230.0                   193.0                   127.0
# 1                  2000.0                   660.0                   500.0
# 2                  1000.0                   767.0                   384.0
# 3                 14000.0                 19000.0                     NaN
# 4                 15000.0                  1000.0                   721.0
#
#    Total_likes
# 0        550.0
# 1       3160.0
# 2       2151.0
# 3          NaN
# 4      16721.0

# %%
# sorting to arrange according to popularity

sorted_trio = actor_trio.sort_values('Total_likes', ascending = False)
Top5 = sorted_trio.head()

# %%
# to get names of top 5 popular trios from dataframe to a list

Top5["Trio"] = Top5['actor_1_name']+" | "+Top5['actor_2_name']+" | "+Top5['actor_3_name']
Top5
# Out:
#          actor_1_name        actor_2_name          actor_3_name  \
# 68          Dev Patel       Nicole Kidman           Rooney Mara
# 24  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 58  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 5       Casey Affleck  Michelle Williams          Kyle Chandler
# 26          Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 68                 33000.0                 96000.0                  9800.0
# 24                 29000.0                 27000.0                 23000.0
# 58                 34000.0                 22000.0                 20000.0
# 5                    518.0                 71000.0                  3300.0
# 26                 27000.0                 23000.0                 23000.0
#
#     Total_likes                                               Trio
# ...

# %%
bar_plot_fun(Top5, "Trio", "Total_likes")

# %% [markdown]
# #### Dev Patel, Nicole Kidman and Rooney Mara trio has received the most likes combined, making it the most popular trio.

# %% [markdown]
# ## Runtime Analysis
#
# There is a column named `Runtime` in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Ploting a `histogram` or `distplot` of seaborn to find the `Runtime` range most of the movies fall into.

# %%
# Runtime histogram/density plot

sns.distplot(movies['Runtime'])
plt.title('Runtime Analysis', fontdict = {'fontsize' : 20, 'color': 'Blue'})
plt.xlabel('Runtime (in minutes)', fontdict = {'fontsize' : 15, 'color': 'Blue'})
plt.show()

# %% [markdown]
# #### Most of the Top 100 movies appear to be sharply 2 hour-long.

# %% [markdown]
# ## R-Rated Movies Analysis
#
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, Let's find the top 10 movies that have the highest number of votes i.e.`CVotesU18`

# %%
# Extracting R-rated movies

R_df = movies[movies['content_rating']=='R']

# sorting in descending order for highest number of votes
PopularR = R_df.sort_values('CVotesU18', ascending = False).head(10)

# %%
PopularR
# Out:
#                                               Title  title_year  budget  \
# 82                                         Deadpool        2016    58.0
# 47                          The Wolf of Wall Street        2013   100.0
# 19                                 Django Unchained        2012   100.0
# 12                               Mad Max: Fury Road        2015   150.0
# 9                                          Whiplash        2014     3.3
# 51                                     The Revenant        2015   135.0
# 86                                   Shutter Island        2010    80.0
# 32                                        Gone Girl        2014    61.0
# 14                         The Grand Budapest Hotel        2014    25.0
# 17  Birdman or (The Unexpected Virtue of Ignorance)        2014    18.0
#
#          Gross       actor_1_name         actor_2_name       actor_3_name  \
# 82  363.024263      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# ...

# %%
bar_plot_fun(PopularR, 'Title', 'CVotesU18')

# %% [markdown]
# #### It seems that many kids are watching Deadpool despite of the movie being R-rated.

# %% [markdown]
# ## Know your Audience!
#
# If we take a look at the last columns in the dataframe, most of these are related to demographics of the voters. We also have three genre columns indicating the genres of a particular movie.

# %% [markdown]
# There are 3 columns in the dataframe - `genre_1`, `genre_2`, and `genre_3`. We need to aggregate a few values over these 3 columns for further analysis.

# %%
# to fetch genre columns and columns consisting votes

genre = movies.iloc[:,11:14]
votes = movies.iloc[:,16:60]

# %%
# Create the dataframe df_by_genre

df_by_genre = pd.concat([genre, votes], axis = 1)
df_by_genre
# Out:
#       genre_1    genre_2    genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0       Drama        NaN        NaN     49673     62055     76838     52238
# 1   Biography      Drama    History     75556    126223    161460     83070
# 2   Animation  Adventure     Comedy     87509    113244    119801     67153
# 3      Comedy      Drama      Music     74245     71191     64640     38831
# 4   Animation  Adventure     Comedy    139773    149992    158704     88289
# 5       Drama        NaN        NaN     18191     33532     46596     29626
# 6       Crime      Drama    History     35421     72285    100793     49236
# 7       Drama     Sci-Fi   Thriller     89986    127616    169693    122275
# 8       Drama    Romance        NaN     16953     22109     31439     19251
# 9       Drama      Music        NaN    110404    161864    132656     56007
# 10      Drama    Romance        NaN     11093     15944     22942     14187
# ...

# %%
# to verify number of columns (should be 47)
df_by_genre.shape
# Out:
# (100, 47)

# %%
# Create a column cnt and initialize it to 1

df_by_genre['cnt'] = 1

# %%
# to check new column
df_by_genre.head()
# Out:
#      genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 0      Drama        NaN      NaN     49673     62055     76838     52238
# 1  Biography      Drama  History     75556    126223    161460     83070
# 2  Animation  Adventure   Comedy     87509    113244    119801     67153
# 3     Comedy      Drama    Music     74245     71191     64640     38831
# 4  Animation  Adventure   Comedy    139773    149992    158704     88289
#
#    CVotes06  CVotes05  CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  \
# 0     23789     10431      4906      3071      2248      5086      183807
# 1     27231      9603      4021      2420      1785      4739      313823
# 2     24210      8542      3349      1872      1123      3450      244433
# 3     17377      8044      3998      2839      2407      6802      157693
# 4     31291     11850      4859      2932      2119      6586      389014
#
#    CVotesFemale  CVotesU18  CVotesU18M  CVotesU18F  CVotes1829  CVotes1829M  \
# ...

# %%
# Group the movies by individual genres

df_by_g1 = df_by_genre.groupby(['genre_1'], axis = 0).sum()
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# genre_1
# Action       156150     89483     61975    162426     9994618       1858890
# Adventure     58559     33174     22018     48100     3535070        802902
# Animation     30718     15733     10026     25193     2282985        724844
# ...

# %%
df_by_g2 = df_by_genre.groupby(['genre_2'], axis = 0).sum()
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
df_by_g3 = df_by_genre.groupby(['genre_3'], axis = 0).sum()
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
# Add the grouped data frames and store it in a new data frame

df_add = df_by_g1.add(df_by_g2, fill_value = 0).add(df_by_g3, fill_value = 0)
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Extract genres with atleast 10 occurences

genre_top10 = df_add[df_add['cnt'] >= 10]
genre_top10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# ...

# %%
# verify rows of genre_top10

genre_top10.shape
# Out:
# (10, 45)

# %%
# Take the mean for every column by dividing with cnt 

genre_top10.iloc[:,0:44] = genre_top10.iloc[:,0:44].div(genre_top10['cnt'], axis=0)
genre_top10.iloc[:,0:44]
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Rounding off the columns of Votes to two decimals

genre_top10.loc[:, "VotesM":"VotesnUS"] = genre_top10.loc[:, "VotesM":"VotesnUS"].round(decimals = 2)

# Checking the dataframe
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
# Converting CVotes to int type

genre_top10.loc[:, "CVotes10":"CVotesnUS"] = genre_top10.loc[:, "CVotes10":"CVotesnUS"].astype("int32")

#checking dataframe

genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action     102144.0  114433.0  150895.0   94262.0   34688.0   12693.0
# Adventure   94596.0  105636.0  138482.0   86367.0   31896.0   11551.0
# Animation   61960.0   72566.0  104837.0   65707.0   22825.0    7551.0
# Biography   47333.0   77867.0  123948.0   74054.0   23644.0    7702.0
# Comedy      60157.0   77173.0  108993.0   69176.0   26099.0    9863.0
# Crime       52229.0   87919.0  129045.0   74671.0   25308.0    8971.0
# Drama       52375.0   75928.0  109339.0   66456.0   23528.0    8497.0
# Romance     42304.0   53037.0   82252.0   54833.0   21637.0    8530.0
# Sci-Fi     136781.0  148873.0  176646.0  106005.0   39518.0   14951.0
# Thriller    83207.0  112730.0  153336.0   90446.0   32003.0   11534.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Action       5386.0    3064.0    2115.0    5524.0    349581.0       67916.0
# ...

# %% [markdown]
# ## Genre Counts!
#
# Let's find out popular genres

# %%
plt.figure(figsize = (15,9))

sns.barplot(x = genre_top10.index, y = genre_top10.cnt)

# adding title and labels
plt.title("Genres and its popularity", fontsize = 25)
plt.xlabel("Genres", fontsize = 20)
plt.ylabel("Votes count", fontsize = 20)
plt.show()

# %% [markdown]
# #### It seems that majority of people enjoy watching Drama a lot followed by Adventure and Action. In order to make a blockbluster movie, one might want to focus on these genres.

# %% [markdown]
# ## Gender and Genre
#
# The Votes- and CVotes-related columns, you might have noticed the suffixes `F` and `M` indicating Female and Male. Since we have the vote counts for both males and females, across various age groups, let's now see how the popularity of genres vary between the two genders in the dataframe.

# %%
# 1st set of heat maps for CVotes-related columns

plt.figure(figsize = (20,10))

# Subplot_1: Male Votes across genres 
plt.subplot(1,2,1)
sns.heatmap((pd.pivot_table(data = genre_top10, index = genre_top10.index, values = ["CVotesU18M","CVotes1829M","CVotes3044M","CVotes45AM"], aggfunc = "mean" )), annot = True, cmap = "YlGnBu")
plt.title("Male Votes for various genres", fontdict = {"fontsize":25, "color": "Blue"})

# Subplot_2: Female Votes across genres 
plt.subplot(1,2,2)
sns.heatmap((pd.pivot_table(data = genre_top10, index = genre_top10.index, values = ["CVotesU18F","CVotes1829F","CVotes3044F","CVotes45AF"], aggfunc = "mean" )), annot = True, cmap = "YlGnBu")
plt.title("Female Votes for various genres", fontdict = {"fontsize":25, "color": "Blue"})

plt.show()

# %% [markdown]
# #### A few inferences that can be seen from the heatmap above is that males have voted more than females, and Sci-Fi appears to be most popular among the 18-29 age group irrespective of their gender.
# #### Under 18 age group is least voted group. Also Age category of 18-29 have voted more than other categories.
# #### Romance and comedy genre is more popular in females as compared to males.
# #### Action categorty is more popular in males as compared to females irrespective of age categories

# %%
# 2nd set of heat maps for Votes-related columns
plt.figure(figsize = (20,10))

# Subplot_1: Males rating across genres
plt.subplot(1,2,1)
plt.title("Male Rating for various genres", fontdict = {"fontsize":20, "color": "Green"})
sns.heatmap((pd.pivot_table(data = genre_top10, index = genre_top10.index, values = ["VotesU18M","Votes1829M","Votes3044M","Votes45AM"], aggfunc = "mean" )), annot = True, cmap = "RdYlGn")

# Subplot_2: Females rating across genres
plt.subplot(1,2,2)
plt.title("Female Rating for various genres", fontdict = {"fontsize":20, "color": "Green"})
sns.heatmap((pd.pivot_table(data = genre_top10, index = genre_top10.index, values = ["VotesU18F","Votes1829F","Votes3044F","Votes45AF"], aggfunc = "mean" )), annot = True, cmap = "RdYlGn")

plt.show()

# %% [markdown]
# #### Sci-Fi appears to be the highest rated genre in the age group of U18 for both males and females. Also, females in this age group have rated it a bit higher than the males in the same age group.
# #### Overall ratings in 18-29 male age group is a bit higher for all genres than ratings of females
# #### Crime genre is highly rated by male under 18 category as compared to female.
# #### Romance category is lowest rated genre by above 45 category irrespective of gender.

# %% [markdown]
# ## US vs non-US Cross Analysis
#
# The dataset contains both the US and non-US movies. Let's analyse how both the US and the non-US voters have responded to the US and the non-US movies.

# %%
# Creating IFUS column

movies['IFUS']=movies['Country'].apply(lambda  x:"USA" if x=='USA' else "non-USA" ) 
movies.head()
# Out:
#               Title  title_year  budget       Gross        actor_1_name  \
# 0           Boyhood        2014     4.0   25.359200      Ellar Coltrane
# 1  12 Years a Slave        2013    20.0   56.667870  QuvenzhanÃ© Wallis
# 2        Inside Out        2015   175.0  356.454367         Amy Poehler
# 3        La La Land        2016    30.0  151.101803        Ryan Gosling
# 4       Toy Story 3        2010   200.0  414.984497           Tom Hanks
#
#         actor_2_name   actor_3_name  actor_1_facebook_likes  \
# 0  Lorelei Linklater  Libby Villari                   230.0
# 1      Scoot McNairy   Taran Killam                  2000.0
# 2       Mindy Kaling  Phyllis Smith                  1000.0
# 3         Emma Stone     Amiée Conn                 14000.0
# 4  John Ratzenberger    Don Rickles                 15000.0
#
#    actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# 0                   193.0                   127.0          7.9      Drama
# ...

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)

plt.figure(figsize = (20,10))

#Subplot 1: Vote count in USA
plt.subplot(1,2,1)
sns.boxplot(x = "IFUS", y = "CVotesUS", data = movies)

# adding title and labels
plt.title("Popularity of movies in USA", fontdict = {"fontsize":25, "color": "Blue"})
plt.xlabel('Movies', fontdict = {"fontsize":15, "color": "Blue"})
plt.ylabel('Vote count', fontdict = {"fontsize":15, "color": "Blue"})

# Subplot 2: Vote count in other countries
plt.subplot(1,2,2)
sns.boxplot(x = "IFUS", y = "CVotesnUS", data = movies)

# adding title and labels
plt.title("Popularity of movies in other countries", fontdict = {"fontsize":25, "color": "Blue"})
plt.xlabel('Movies', fontdict = {"fontsize":15, "color": "Blue"})
plt.ylabel('Vote count', fontdict = {"fontsize":15, "color": "Blue"})

plt.show()

# %% [markdown]
# #### Outliers can be seen for both plots for USA movies. It seems that for some USA movies, vote count is maximum.
# #### In other countries, USA movies are more popular than non-USA movies.

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)


plt.figure(figsize = (20,10))

#Subplot 1: Movie Ratings in USA
plt.subplot(1,2,1)
sns.boxplot(x = "IFUS", y = "VotesUS", data = movies)

# adding title and labels
plt.title("Movie Ratings in USA", fontdict = {"fontsize":25, "color": "Orange"})
plt.xlabel('Movies', fontdict = {"fontsize":15, "color": "Orange"})
plt.ylabel('Ratings', fontdict = {"fontsize":15, "color": "Orange"})

# Subplot 2: Movie Ratings in other countries
plt.subplot(1,2,2)
sns.boxplot(x = "IFUS", y = "VotesnUS", data = movies)

# adding title and labels
plt.title("Movie Ratings in other countries", fontdict = {"fontsize":25, "color": "Orange"})
plt.xlabel('Movies', fontdict = {"fontsize":15, "color": "Orange"})
plt.ylabel('Ratings', fontdict = {"fontsize":15, "color": "Orange"})

plt.show()

# %% [markdown]
# #### USA movies are highly rated irrespective of countries
# #### It seems that majority Rating for non-USA movies in other countries lies between 7.5 and 7.9

# %% [markdown]
# ## Top 1000 Voters Vs Genres
#
# The column `CVotes1000`represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.

# %%
# Sorting by CVotes1000

genre_top10.sort_values('CVotes1000',ascending = False, inplace = True)
genre_top10
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi     136781.0  148873.0  176646.0  106005.0   39518.0   14951.0
# Action     102144.0  114433.0  150895.0   94262.0   34688.0   12693.0
# Thriller    83207.0  112730.0  153336.0   90446.0   32003.0   11534.0
# Adventure   94596.0  105636.0  138482.0   86367.0   31896.0   11551.0
# Crime       52229.0   87919.0  129045.0   74671.0   25308.0    8971.0
# Comedy      60157.0   77173.0  108993.0   69176.0   26099.0    9863.0
# Biography   47333.0   77867.0  123948.0   74054.0   23644.0    7702.0
# Drama       52375.0   75928.0  109339.0   66456.0   23528.0    8497.0
# Animation   61960.0   72566.0  104837.0   65707.0   22825.0    7551.0
# Romance     42304.0   53037.0   82252.0   54833.0   21637.0    8530.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  CVotesMale  CVotesFemale  \
# Sci-Fi       6583.0    3876.0    2715.0    6731.0    422437.0       83618.0
# ...

# %%
# Bar plot
plt.figure(figsize = (15,10))
sns.barplot(data = genre_top10, x = genre_top10.index , y = "CVotes1000")

#adding and formatiing tile and labels
plt.title("Popularity among Top 1000 voters", fontdict = {"fontsize":25, "color": "Red"})
plt.xlabel('Genres', fontdict = {"fontsize": 20, "color": "Red"})
plt.ylabel('Votes', fontdict = {"fontsize": 20, "color": "Red"})

plt.show()

# %% [markdown]
# #### `Sci-Fi` genre seems to be most popular among the top 1000 voters, then comes `Action` and `thriller` movies. The genre `Romance` seems to be most unpopular among the top 1000 voters.

# %% [markdown]
# ## Conclusions from Anaysis

# %% [markdown]
# #### 1. Star Wars: The Force Awakens has made the most profit & liked by both audience and critics. Also Deadpool, Django Unchanged, Whiplash and Gone Girl are some of the movies which are popular. These movies can be studied and further analysed to find reasons behind its success.
# #### 2. The new movie can belong to either category R or PG-13 as these categories are popular among audience
# #### 3. Budget of the movie has no significant effect on the movie becoming a success as we have seen that movies with huge budget has made very less profit. Also movies with small budget has made a huge profit. Budget for the new movie can be anything that suits the pockets!
# #### 4. Genres plays an important role in deciding the fate of a movie. One might want to stick to genres which are popular in order to produce a blockbuster!
# #### 5. Konwing the audience is very crucial. If one is looking to target audience with age group of 45 and above then romance genre is to be avoided. If the target audience is under 29, then sci-fic is the best choice.
# #### 6. Thriller and Action genre is very popular in under 44 age group irrespective of the gender, so these genres will catch majority of the audience.
# #### 7. Romance and comedy genres are more popular in females as compared to males, so if the aim is to attract female audience then one should go for these genres!
